# %%
import pandas as pd

# %%
df_res = pd.read_csv("errs_by_model.csv")
df_res.index = pd.Series(df_res["Model"], name="Model")
df_res.plot(kind="bar", ylabel="error rate %", stacked=True, rot=20, title="Pascal architecture")
# Out:
# <Axes: title={'center': 'Pascal architecture'}, xlabel='Model', ylabel='error rate %'>
